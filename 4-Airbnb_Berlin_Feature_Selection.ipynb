# %% [markdown]
# <a href="https://colab.research.google.com/github/rafatb/Berlin_Airbnb_Price_Prediction/blob/main/4-Airbnb_Berlin_Feature_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Stage 4 - Airbnb Berlin - Feature Selection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pyMechkar
# Out:
# Collecting pyMechkar
#   Downloading pyMechkar-0.1.6-py3-none-any.whl.metadata (1.0 kB)
# Downloading pyMechkar-0.1.6-py3-none-any.whl (14 kB)
# Installing collected packages: pyMechkar
# Successfully installed pyMechkar-0.1.6

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle("/content/drive/MyDrive/kaggle/berline/ready_for_feature_selection.pkl")
df.head()
# Out:
#    Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0           100.0             10.0                10.0            10.0
# 1            92.0              9.0                 9.0             9.0
# 2            96.0             10.0                10.0            10.0
# 3           100.0             10.0                10.0            10.0
# 4            93.0             10.0                10.0             9.0
#
#    Communication Rating  Location Rating  Value Rating  Price  Reviews  \
# 0                  10.0              9.0          10.0   17.0      7.0
# 1                   9.0             10.0           9.0   90.0    144.0
# 2                  10.0             10.0          10.0   33.0    229.0
# 3                  10.0             10.0          10.0  180.0      6.0
# 4                  10.0              9.0           9.0   70.0     23.0
#
#    Bedrooms  ...  Instant Bookable  Is Exact Location  Postal Code  \
# 0       1.0  ...             False               True        10437
# 1       1.0  ...             False               True        10405
# 2       1.0  ...             False               True        10437
# 3       4.0  ...             False              False        10405
# 4       0.0  ...             False               True        10437
#
#    Property Type  Host Response Time  Neighborhood Group        Room Type  \
# 0      Apartment        within a day              Pankow     Private room
# 1      Apartment        within a day              Pankow  Entire home/apt
# 2      Apartment      within an hour              Pankow     Private room
# 3      Apartment        within a day              Pankow  Entire home/apt
# 4      Apartment        within a day              Pankow  Entire home/apt
#
#    Distance From Center  Distance From Center Grouped  Host Since Year Old
# 0                   5.1                   Circle_4_KM                   17
# 1                   3.7                   Circle_2_KM                   17
# 2                   4.6                   Circle_4_KM                   16
# 3                   3.5                   Circle_2_KM                   16
# 4                   5.0                   Circle_4_KM                   16
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall Rating                23536 non-null  float64
#  1   Accuracy Rating               23536 non-null  float64
#  2   Cleanliness Rating            23536 non-null  float64
#  3   Checkin Rating                23536 non-null  float64
#  4   Communication Rating          23536 non-null  float64
#  5   Location Rating               23536 non-null  float64
#  6   Value Rating                  23536 non-null  float64
#  7   Price                         23536 non-null  float64
#  8   Reviews                       23536 non-null  float64
#  9   Bedrooms                      23536 non-null  float64
#  10  Beds                          23536 non-null  float64
#  11  Bathrooms                     23536 non-null  float64
#  12  Is Superhost                  23536 non-null  bool
#  13  Latitude                      23536 non-null  float64
#  14  Longitude                     23536 non-null  float64
#  15  Accomodates                   23536 non-null  float64
#  16  Guests Included               23536 non-null  float64
#  17  Min Nights                    23536 non-null  float64
#  18  Instant Bookable              23536 non-null  bool
#  19  Is Exact Location             23536 non-null  bool
#  20  Postal Code                   23536 non-null  object
#  21  Property Type                 23536 non-null  object
#  22  Host Response Time            23536 non-null  object
#  23  Neighborhood Group            23536 non-null  object
#  24  Room Type                     23536 non-null  object
#  25  Distance From Center          23536 non-null  float64
#  26  Distance From Center Grouped  23536 non-null  category
#  27  Host Since Year Old           23536 non-null  int64
# dtypes: bool(3), category(1), float64(18), int64(1), object(5)
# memory usage: 4.4+ MB

# %% [markdown]
# #deleting un necesssary features

# %%
df = df.drop(columns=['Distance From Center Grouped','Longitude', 'Latitude','Postal Code',], inplace=False)

# %% [markdown]
# #Lable encoding

# %%
pd.set_option('display.max_columns', None)

# %%
categorical_columns =  df.select_dtypes(include = ['object','category']).columns
categorical_columns
# Out:
# Index(['Property Type', 'Host Response Time', 'Neighborhood Group',
#        'Room Type'],
#       dtype='object')

# %%
categorical_columns =  df.select_dtypes(include = ['object','category']).columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in categorical_columns:
  print
  df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0           100.0             10.0                10.0            10.0
# 1            92.0              9.0                 9.0             9.0
# 2            96.0             10.0                10.0            10.0
# 3           100.0             10.0                10.0            10.0
# 4            93.0             10.0                10.0             9.0
#
#    Communication Rating  Location Rating  Value Rating  Price  Reviews  \
# 0                  10.0              9.0          10.0   17.0      7.0
# 1                   9.0             10.0           9.0   90.0    144.0
# 2                  10.0             10.0          10.0   33.0    229.0
# 3                  10.0             10.0          10.0  180.0      6.0
# 4                  10.0              9.0           9.0   70.0     23.0
#
#    Bedrooms  Beds  Bathrooms  Is Superhost  Accomodates  Guests Included  \
# 0       1.0   1.0        1.0         False          2.0              1.0
# 1       1.0   2.0        1.0         False          4.0              2.0
# 2       1.0   2.0        1.0          True          2.0              1.0
# 3       4.0   7.0        0.0         False          0.0              5.0
# 4       0.0   1.0        1.0         False          1.0              1.0
#
#    Min Nights  Instant Bookable  Is Exact Location  Property Type  \
# 0         2.0             False               True              1
# 1         0.0             False               True              1
# 2         2.0             False               True              1
# 3         6.0             False              False              1
# 4         0.0             False               True              1
#
#    Host Response Time  Neighborhood Group  Room Type  Distance From Center  \
# 0                   2                   6          1                   5.1
# 1                   2                   6          0                   3.7
# 2                   4                   6          1                   4.6
# 3                   2                   6          0                   3.5
# 4                   2                   6          0                   5.0
#
#    Host Since Year Old
# 0                   17
# 1                   17
# 2                   16
# 3                   16
# 4                   16

# %% [markdown]
# # Hyperparameters

# %%
#Creating Variables dataframeS
varSel = pd.DataFrame({'Variable': df.columns.drop('Price')})
varSel

# y=df['Price']
# X = df.drop(columns=['Price'])
# Out:
#                 Variable
# 0         Overall Rating
# 1        Accuracy Rating
# 2     Cleanliness Rating
# 3         Checkin Rating
# 4   Communication Rating
# 5        Location Rating
# 6           Value Rating
# 7                Reviews
# 8               Bedrooms
# 9                   Beds
# 10             Bathrooms
# 11          Is Superhost
# 12           Accomodates
# 13       Guests Included
# 14            Min Nights
# 15      Instant Bookable
# 16     Is Exact Location
# 17         Property Type
# 18    Host Response Time
# 19    Neighborhood Group
# 20             Room Type
# 21  Distance From Center
# 22   Host Since Year Old

# %%
from pyMechkar.analysis import Table1
nm = df.columns.drop('Price')
nm = nm.append(pd.Index(['Price']))
nm
# Out:
# Index(['Overall Rating', 'Accuracy Rating', 'Cleanliness Rating',
#        'Checkin Rating', 'Communication Rating', 'Location Rating',
#        'Value Rating', 'Reviews', 'Bedrooms', 'Beds', 'Bathrooms',
#        'Is Superhost', 'Accomodates', 'Guests Included', 'Min Nights',
#        'Instant Bookable', 'Is Exact Location', 'Property Type',
#        'Host Response Time', 'Neighborhood Group', 'Room Type',
#        'Distance From Center', 'Host Since Year Old', 'Price'],
#       dtype='object')

# %%
df2 = df[nm].copy()
df2.head()
# Out:
#    Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0           100.0             10.0                10.0            10.0
# 1            92.0              9.0                 9.0             9.0
# 2            96.0             10.0                10.0            10.0
# 3           100.0             10.0                10.0            10.0
# 4            93.0             10.0                10.0             9.0
#
#    Communication Rating  Location Rating  Value Rating  Reviews  Bedrooms  \
# 0                  10.0              9.0          10.0      7.0       1.0
# 1                   9.0             10.0           9.0    144.0       1.0
# 2                  10.0             10.0          10.0    229.0       1.0
# 3                  10.0             10.0          10.0      6.0       4.0
# 4                  10.0              9.0           9.0     23.0       0.0
#
#    Beds  Bathrooms  Is Superhost  Accomodates  Guests Included  Min Nights  \
# 0   1.0        1.0         False          2.0              1.0         2.0
# 1   2.0        1.0         False          4.0              2.0         0.0
# 2   2.0        1.0          True          2.0              1.0         2.0
# 3   7.0        0.0         False          0.0              5.0         6.0
# 4   1.0        1.0         False          1.0              1.0         0.0
#
#    Instant Bookable  Is Exact Location  Property Type  Host Response Time  \
# 0             False               True              1                   2
# 1             False               True              1                   2
# 2             False               True              1                   4
# 3             False              False              1                   2
# 4             False               True              1                   2
#
#    Neighborhood Group  Room Type  Distance From Center  Host Since Year Old  \
# 0                   6          1                   5.1                   17
# 1                   6          0                   3.7                   17
# 2                   6          1                   4.6                   16
# 3                   6          0                   3.5                   16
# 4                   6          0                   5.0                   16
#
#    Price
# 0   17.0
# 1   90.0
# 2   33.0
# 3  180.0
# 4   70.0

# %% [markdown]
# #Multivariable Analysis

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.linear_model import Ridge

# %%
### drop na
df2 = df2.dropna()
df.shape
# Out:
# (23536, 24)

# %%
## remove unnecessary vars
X = df2.iloc[:,:-1]
X
# Out:
#        Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0               100.0             10.0                10.0            10.0
# 1                92.0              9.0                 9.0             9.0
# 2                96.0             10.0                10.0            10.0
# 3               100.0             10.0                10.0            10.0
# 4                93.0             10.0                10.0             9.0
# ...               ...              ...                 ...             ...
# 23531           100.0             10.0                10.0            10.0
# 23532            60.0              6.0                 6.0             8.0
# 23533           100.0             10.0                10.0            10.0
# 23534            80.0              8.0                 8.0            10.0
# 23535           100.0             10.0                 9.0            10.0
#
#        Communication Rating  Location Rating  Value Rating  Reviews  Bedrooms  \
# 0                      10.0              9.0          10.0      7.0       1.0
# 1                       9.0             10.0           9.0    144.0       1.0
# 2                      10.0             10.0          10.0    229.0       1.0
# 3                      10.0             10.0          10.0      6.0       4.0
# 4                      10.0              9.0           9.0     23.0       0.0
# ...                     ...              ...           ...      ...       ...
# 23531                   9.0              9.0          10.0      0.0       1.0
# 23532                   8.0              6.0           6.0      0.0       2.0
# 23533                  10.0              8.0           8.0      0.0       1.0
# 23534                  10.0              7.0           7.0      0.0       3.0
# 23535                  10.0              9.0           9.0      0.0       2.0
#
#        Beds  Bathrooms  Is Superhost  Accomodates  Guests Included  \
# 0       1.0        1.0         False          2.0              1.0
# 1       2.0        1.0         False          4.0              2.0
# 2       2.0        1.0          True          2.0              1.0
# 3       7.0        0.0         False          0.0              5.0
# 4       1.0        1.0         False          1.0              1.0
# ...     ...        ...           ...          ...              ...
# 23531   2.0        1.0         False          3.0              1.0
# 23532   2.0        1.0         False          2.0              2.0
# 23533   1.0        0.0         False          1.0              1.0
# 23534   4.0        1.0         False          0.0              1.0
# 23535   2.0        1.0         False          3.0              1.0
#
#        Min Nights  Instant Bookable  Is Exact Location  Property Type  \
# 0             2.0             False               True              1
# 1             0.0             False               True              1
# 2             2.0             False               True              1
# 3             6.0             False              False              1
# 4             0.0             False               True              1
# ...           ...               ...                ...            ...
# 23531         0.0              True              False              1
# 23532         5.0              True               True              1
# 23533         2.0              True               True              1
# 23534         2.0              True               True              1
# 23535         2.0              True              False              1
#
#        Host Response Time  Neighborhood Group  Room Type  \
# 0                       2                   6          1
# 1                       2                   6          0
# 2                       4                   6          1
# 3                       2                   6          0
# 4                       2                   6          0
# ...                   ...                 ...        ...
# 23531                   3                   9          0
# 23532                   1                   6          1
# 23533                   1                   5          1
# 23534                   1                  11          0
# 23535                   1                   6          0
#
#        Distance From Center  Host Since Year Old
# 0                       5.1                   17
# 1                       3.7                   17
# 2                       4.6                   16
# 3                       3.5                   16
# 4                       5.0                   16
# ...                     ...                  ...
# 23531                  18.7                    7
# 23532                  15.4                    6
# 23533                   5.9                   11
# 23534                  12.7                    6
# 23535                   6.4                    7
#
# [23536 rows x 23 columns]

# %%
y = df2.iloc[:,-1:]
print([X.shape,y.shape])
# Out:
# [(23536, 23), (23536, 1)]

# %% [markdown]
# ##Variable Selection using LASSO (L1 penalization)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
lassomod = Lasso(alpha=0.01).fit(X, y)
model = SelectFromModel(lassomod, prefit=True)
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
varSel['Lasso'] = model.get_support().astype('int64')

# %% [markdown]
# ##Variable Selection using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel

rfmod = RandomForestRegressor().fit(X, y)
model = SelectFromModel(rfmod, prefit=True)
model.get_support()
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False,  True, False, False,  True,  True,
#        False,  True, False,  True, False])

# %%
varSel['RandomForest'] = model.get_support().astype('int64')

# %% [markdown]
# ##Variable Selection using Gradient Boosting classification

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel

gbmod = GradientBoostingClassifier().fit(X, y)
model = SelectFromModel(gbmod, prefit=True)
model.get_support()
# Out:
# array([ True, False, False, False, False, False,  True,  True,  True,
#         True, False, False, False,  True,  True, False, False,  True,
#        False, False, False,  True, False])

# %%
varSel['GradientBoost'] = model.get_support().astype('int64')

# %% [markdown]
# ##Variable Selection using SVM classification

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

svmmod = LinearSVC(C=0.01, penalty="l1",dual=False).fit(X, y)
model = SelectFromModel(svmmod, prefit=True)
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
varSel['SVM'] = model.get_support().astype('int64')

# %%
# import numpy as np
# import pandas as pd
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import ElasticNet
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics import mean_squared_error

# elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
# elastic_net.fit(X, y)

# # Use SelectFromModel to extract important features
# selector = SelectFromModel(elastic_net, prefit=True)  # Prefit=True means model is already trained
# selector.get_support()  # Boolean mask for selected features

# %%
# varSel['elastic_net'] = selector.get_support().astype('int64')

# %% [markdown]
# #Variable Selection using Ridge

# %%
ridge = Ridge(alpha=5).fit(X, y)
model = SelectFromModel(ridge, prefit=True)
# print(f"get_support: {model.get_support()}")
# print(f"coef: {ridge.coef_}")
varSel['Ridge'] = model.get_support().astype('int64')

# %%
alpha_values = np.logspace(-1, 1, 10)  # 10 values between 10^-4 and 10^4

# %%
from sklearn.linear_model import RidgeCV

# RidgeCV automatically finds the best alpha
ridge_cv = RidgeCV(alphas=alpha_values, store_cv_values=True)
ridge_cv.fit(X, y)

# Print the best alpha
print(f"Best alpha: {ridge_cv.alpha_}")
# Out:
# Best alpha: 10.0

# %% [markdown]
# ##Summarization and Selection of Variables

# %%
varSel.head(30)
# Out:
#                 Variable  Lasso  RandomForest  GradientBoost  SVM  Ridge
# 0         Overall Rating      1             0              1    1      0
# 1        Accuracy Rating      1             0              0    1      0
# 2     Cleanliness Rating      1             0              0    1      0
# 3         Checkin Rating      1             0              0    1      1
# 4   Communication Rating      1             1              0    1      0
# 5        Location Rating      1             0              0    1      1
# 6           Value Rating      1             0              1    1      0
# 7                Reviews      1             0              1    1      0
# 8               Bedrooms      1             0              1    1      1
# 9                   Beds      1             0              1    1      0
# 10             Bathrooms      1             0              0    1      0
# 11          Is Superhost      1             0              0    1      0
# 12           Accomodates      1             0              0    1      0
# 13       Guests Included      1             1              1    1      1
# 14            Min Nights      1             0              1    1      0
# 15      Instant Bookable      1             0              0    1      1
# 16     Is Exact Location      1             1              0    1      1
# 17         Property Type      1             1              1    1      0
# 18    Host Response Time      1             0              0    1      0
# 19    Neighborhood Group      1             1              0    1      0
# 20             Room Type      1             0              0    1      1
# 21  Distance From Center      1             1              1    1      0
# 22   Host Since Year Old      1             0              0    1      0

# %%
varSel['Sum'] =  np.sum(varSel[["Lasso",	"RandomForest",	"GradientBoost"	,"SVM","Ridge"]],axis=1)
varSel
# Out:
#                 Variable  Lasso  RandomForest  GradientBoost  SVM  Ridge  Sum
# 0         Overall Rating      1             0              1    1      0    3
# 1        Accuracy Rating      1             0              0    1      0    2
# 2     Cleanliness Rating      1             0              0    1      0    2
# 3         Checkin Rating      1             0              0    1      1    3
# 4   Communication Rating      1             1              0    1      0    3
# 5        Location Rating      1             0              0    1      1    3
# 6           Value Rating      1             0              1    1      0    3
# 7                Reviews      1             0              1    1      0    3
# 8               Bedrooms      1             0              1    1      1    4
# 9                   Beds      1             0              1    1      0    3
# 10             Bathrooms      1             0              0    1      0    2
# 11          Is Superhost      1             0              0    1      0    2
# 12           Accomodates      1             0              0    1      0    2
# 13       Guests Included      1             1              1    1      1    5
# 14            Min Nights      1             0              1    1      0    3
# 15      Instant Bookable      1             0              0    1      1    3
# 16     Is Exact Location      1             1              0    1      1    4
# 17         Property Type      1             1              1    1      0    4
# 18    Host Response Time      1             0              0    1      0    2
# 19    Neighborhood Group      1             1              0    1      0    3
# 20             Room Type      1             0              0    1      1    3
# 21  Distance From Center      1             1              1    1      0    4
# 22   Host Since Year Old      1             0              0    1      0    2

# %%
varSel.groupby('Sum')['Variable'].count()
# Out:
# Sum
# 2     7
# 3    11
# 4     4
# 5     1
# Name: Variable, dtype: int64

# %%
varSel[varSel['Sum']==5]
# Out:
#            Variable  Lasso  RandomForest  GradientBoost  SVM  Ridge  Sum
# 13  Guests Included      1             1              1    1      1    5

# %%
varSel[varSel['Sum']>=4]
# Out:
#                 Variable  Lasso  RandomForest  GradientBoost  SVM  Ridge  Sum
# 8               Bedrooms      1             0              1    1      1    4
# 13       Guests Included      1             1              1    1      1    5
# 16     Is Exact Location      1             1              0    1      1    4
# 17         Property Type      1             1              1    1      0    4
# 21  Distance From Center      1             1              1    1      0    4

# %%
varSel[varSel['Sum']>=3]
# Out:
#                 Variable  Lasso  RandomForest  GradientBoost  SVM  Ridge  Sum
# 0         Overall Rating      1             0              1    1      0    3
# 3         Checkin Rating      1             0              0    1      1    3
# 4   Communication Rating      1             1              0    1      0    3
# 5        Location Rating      1             0              0    1      1    3
# 6           Value Rating      1             0              1    1      0    3
# 7                Reviews      1             0              1    1      0    3
# 8               Bedrooms      1             0              1    1      1    4
# 9                   Beds      1             0              1    1      0    3
# 13       Guests Included      1             1              1    1      1    5
# 14            Min Nights      1             0              1    1      0    3
# 15      Instant Bookable      1             0              0    1      1    3
# 16     Is Exact Location      1             1              0    1      1    4
# 17         Property Type      1             1              1    1      0    4
# 19    Neighborhood Group      1             1              0    1      0    3
# 20             Room Type      1             0              0    1      1    3
# 21  Distance From Center      1             1              1    1      0    4

# %%
varSel[varSel['Sum']>=2]
# Out:
#                 Variable  Lasso  RandomForest  GradientBoost  SVM  Ridge  Sum
# 0         Overall Rating      1             0              1    1      0    3
# 1        Accuracy Rating      1             0              0    1      0    2
# 2     Cleanliness Rating      1             0              0    1      0    2
# 3         Checkin Rating      1             0              0    1      1    3
# 4   Communication Rating      1             1              0    1      0    3
# 5        Location Rating      1             0              0    1      1    3
# 6           Value Rating      1             0              1    1      0    3
# 7                Reviews      1             0              1    1      0    3
# 8               Bedrooms      1             0              1    1      1    4
# 9                   Beds      1             0              1    1      0    3
# 10             Bathrooms      1             0              0    1      0    2
# 11          Is Superhost      1             0              0    1      0    2
# 12           Accomodates      1             0              0    1      0    2
# 13       Guests Included      1             1              1    1      1    5
# 14            Min Nights      1             0              1    1      0    3
# 15      Instant Bookable      1             0              0    1      1    3
# 16     Is Exact Location      1             1              0    1      1    4
# 17         Property Type      1             1              1    1      0    4
# 18    Host Response Time      1             0              0    1      0    2
# 19    Neighborhood Group      1             1              0    1      0    3
# 20             Room Type      1             0              0    1      1    3
# 21  Distance From Center      1             1              1    1      0    4
# 22   Host Since Year Old      1             0              0    1      0    2

# %% [markdown]
# #Creating DataFrame with most valuable variables
# We select the variables that are recommended by 3 or more models

# %%
final_vars = varSel[varSel['Sum']>=3]['Variable'].tolist()
df_model = df[final_vars].copy()
## add our Y
df_model['Price'] = df['Price'].copy()
df_model.head()
# Out:
#    Overall Rating  Checkin Rating  Communication Rating  Location Rating  \
# 0           100.0            10.0                  10.0              9.0
# 1            92.0             9.0                   9.0             10.0
# 2            96.0            10.0                  10.0             10.0
# 3           100.0            10.0                  10.0             10.0
# 4            93.0             9.0                  10.0              9.0
#
#    Value Rating  Reviews  Bedrooms  Beds  Guests Included  Min Nights  \
# 0          10.0      7.0       1.0   1.0              1.0         2.0
# 1           9.0    144.0       1.0   2.0              2.0         0.0
# 2          10.0    229.0       1.0   2.0              1.0         2.0
# 3          10.0      6.0       4.0   7.0              5.0         6.0
# 4           9.0     23.0       0.0   1.0              1.0         0.0
#
#    Instant Bookable  Is Exact Location  Property Type  Neighborhood Group  \
# 0             False               True              1                   6
# 1             False               True              1                   6
# 2             False               True              1                   6
# 3             False              False              1                   6
# 4             False               True              1                   6
#
#    Room Type  Distance From Center  Price
# 0          1                   5.1   17.0
# 1          0                   3.7   90.0
# 2          1                   4.6   33.0
# 3          0                   3.5  180.0
# 4          0                   5.0   70.0

# %%
df_model.shape
# Out:
# (23536, 17)

# %% [markdown]
# the selected features are

# %%
final_vars
# Out:
# ['Overall Rating',
#  'Checkin Rating',
#  'Communication Rating',
#  'Location Rating',
#  'Value Rating',
#  'Reviews',
#  'Bedrooms',
#  'Beds',
#  'Guests Included',
#  'Min Nights',
#  'Instant Bookable',
#  'Is Exact Location',
#  'Property Type',
#  'Neighborhood Group',
#  'Room Type',
#  'Distance From Center']

# %%
df_model.to_csv('/content/drive/MyDrive/kaggle/berline/after_feature_selection.csv')

# %%
varSel.to_csv("/content/drive/MyDrive/kaggle/berline/feature_selection_results.csv")
