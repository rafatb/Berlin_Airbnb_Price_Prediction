# %% [markdown]
# <a href="https://colab.research.google.com/github/rafatb/Berlin_Airbnb_Price_Prediction/blob/main/3_Airbnb_Berlin_Feature_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Stage 4 - Airbnb Berlin - Feature Selection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyMechkar
# Out:
# Requirement already satisfied: pyMechkar in /usr/local/lib/python3.11/dist-packages (0.1.6)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_pickle("/content/drive/MyDrive/kaggle/berline/ready_for_feature_selection.pkl")
df.head()
# Out:
#    Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0           100.0             10.0                10.0            10.0
# 1            92.0              9.0                 9.0             9.0
# 2            96.0             10.0                10.0            10.0
# 3           100.0             10.0                10.0            10.0
# 4            93.0             10.0                10.0             9.0
#
#    Communication Rating  Location Rating  Value Rating  Price  Reviews  \
# 0                  10.0              9.0          10.0   17.0      7.0
# 1                   9.0             10.0           9.0   90.0    144.0
# 2                  10.0             10.0          10.0   33.0    229.0
# 3                  10.0             10.0          10.0  180.0      6.0
# 4                  10.0              9.0           9.0   70.0     23.0
#
#    Bedrooms  Beds  Bathrooms  Is Superhost  Latitude  Longitude  Accomodates  \
# 0       1.0   1.0        1.0         False  52.54851   13.40455          2.0
# 1       1.0   2.0        1.0         False  52.53500   13.41758          4.0
# 2       1.0   2.0        1.0          True  52.54316   13.41509          2.0
# 3       4.0   7.0        0.0         False  52.53303   13.41605          0.0
# 4       0.0   1.0        1.0         False  52.54785   13.40556          1.0
#
#    Guests Included  Min Nights  Instant Bookable  Is Exact Location  \
# 0              1.0         2.0             False               True
# 1              2.0         0.0             False               True
# 2              1.0         2.0             False               True
# 3              5.0         6.0             False              False
# 4              1.0         0.0             False               True
#
#   Postal Code Property Type Host Response Time Neighborhood Group  \
# 0       10437     Apartment       within a day             Pankow
# 1       10405     Apartment       within a day             Pankow
# 2       10437     Apartment     within an hour             Pankow
# 3       10405     Apartment       within a day             Pankow
# 4       10437     Apartment       within a day             Pankow
#
#          Room Type  Distance From Center Distance From Center Grouped  \
# 0     Private room                   5.1                  Circle_4_KM
# 1  Entire home/apt                   3.7                  Circle_2_KM
# 2     Private room                   4.6                  Circle_4_KM
# 3  Entire home/apt                   3.5                  Circle_2_KM
# 4  Entire home/apt                   5.0                  Circle_4_KM
#
#    Host Since Year Old
# 0                   17
# 1                   17
# 2                   16
# 3                   16
# 4                   16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall Rating                23536 non-null  float64
#  1   Accuracy Rating               23536 non-null  float64
#  2   Cleanliness Rating            23536 non-null  float64
#  3   Checkin Rating                23536 non-null  float64
#  4   Communication Rating          23536 non-null  float64
#  5   Location Rating               23536 non-null  float64
#  6   Value Rating                  23536 non-null  float64
#  7   Price                         23536 non-null  float64
#  8   Reviews                       23536 non-null  float64
#  9   Bedrooms                      23536 non-null  float64
#  10  Beds                          23536 non-null  float64
#  11  Bathrooms                     23536 non-null  float64
#  12  Is Superhost                  23536 non-null  bool
#  13  Latitude                      23536 non-null  float64
#  14  Longitude                     23536 non-null  float64
#  15  Accomodates                   23536 non-null  float64
#  16  Guests Included               23536 non-null  float64
#  17  Min Nights                    23536 non-null  float64
#  18  Instant Bookable              23536 non-null  bool
#  19  Is Exact Location             23536 non-null  bool
#  20  Postal Code                   23536 non-null  object
#  21  Property Type                 23536 non-null  object
#  22  Host Response Time            23536 non-null  object
#  23  Neighborhood Group            23536 non-null  object
#  24  Room Type                     23536 non-null  object
#  25  Distance From Center          23536 non-null  float64
#  26  Distance From Center Grouped  23536 non-null  category
#  27  Host Since Year Old           23536 non-null  int64
# dtypes: bool(3), category(1), float64(18), int64(1), object(5)
# memory usage: 4.4+ MB

# %% [markdown]
# #deleting un necesssary features

# %%
df = df.drop(columns=['Longitude', 'Latitude'], inplace=False)

# %% [markdown]
# #Lable encoding

# %%
pd.set_option('display.max_columns', None)

# %%
categorical_columns =  df.select_dtypes(include = ['object','category']).columns
categorical_columns
# Out:
# Index(['Postal Code', 'Property Type', 'Host Response Time',
#        'Neighborhood Group', 'Room Type', 'Distance From Center Grouped'],
#       dtype='object')

# %%
categorical_columns =  df.select_dtypes(include = ['object','category']).columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in categorical_columns:
  print
  df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0           100.0             10.0                10.0            10.0
# 1            92.0              9.0                 9.0             9.0
# 2            96.0             10.0                10.0            10.0
# 3           100.0             10.0                10.0            10.0
# 4            93.0             10.0                10.0             9.0
#
#    Communication Rating  Location Rating  Value Rating  Price  Reviews  \
# 0                  10.0              9.0          10.0   17.0      7.0
# 1                   9.0             10.0           9.0   90.0    144.0
# 2                  10.0             10.0          10.0   33.0    229.0
# 3                  10.0             10.0          10.0  180.0      6.0
# 4                  10.0              9.0           9.0   70.0     23.0
#
#    Bedrooms  Beds  Bathrooms  Is Superhost  Latitude  Longitude  Accomodates  \
# 0       1.0   1.0        1.0         False  52.54851   13.40455          2.0
# 1       1.0   2.0        1.0         False  52.53500   13.41758          4.0
# 2       1.0   2.0        1.0          True  52.54316   13.41509          2.0
# 3       4.0   7.0        0.0         False  52.53303   13.41605          0.0
# 4       0.0   1.0        1.0         False  52.54785   13.40556          1.0
#
#    Guests Included  Min Nights  Instant Bookable  Is Exact Location  \
# 0              1.0         2.0             False               True
# 1              2.0         0.0             False               True
# 2              1.0         2.0             False               True
# 3              5.0         6.0             False              False
# 4              1.0         0.0             False               True
#
#    Postal Code  Property Type  Host Response Time  Neighborhood Group  \
# 0           24              1                   2                   6
# 1           18              1                   2                   6
# 2           24              1                   4                   6
# 3           18              1                   2                   6
# 4           24              1                   2                   6
#
#    Room Type  Distance From Center  Distance From Center Grouped  \
# 0          1                   5.1                             9
# 1          0                   3.7                             8
# 2          1                   4.6                             9
# 3          0                   3.5                             8
# 4          0                   5.0                             9
#
#    Host Since Year Old
# 0                   17
# 1                   17
# 2                   16
# 3                   16
# 4                   16

# %% [markdown]
# # Hyperparameters

# %%
#Creating Variables dataframeS
varSel = pd.DataFrame({'Variable': df.columns.drop('Price')})
varSel

# y=df['Price']
# X = df.drop(columns=['Price'])
# Out:
#                         Variable
# 0                 Overall Rating
# 1                Accuracy Rating
# 2             Cleanliness Rating
# 3                 Checkin Rating
# 4           Communication Rating
# 5                Location Rating
# 6                   Value Rating
# 7                        Reviews
# 8                       Bedrooms
# 9                           Beds
# 10                     Bathrooms
# 11                  Is Superhost
# 12                      Latitude
# 13                     Longitude
# 14                   Accomodates
# 15               Guests Included
# 16                    Min Nights
# 17              Instant Bookable
# 18             Is Exact Location
# 19                   Postal Code
# 20                 Property Type
# 21            Host Response Time
# 22            Neighborhood Group
# 23                     Room Type
# 24          Distance From Center
# 25  Distance From Center Grouped
# 26           Host Since Year Old

# %%
from pyMechkar.analysis import Table1
nm = df.columns.drop('Price')
nm = nm.append(pd.Index(['Price']))
nm
# Out:
# Index(['Overall Rating', 'Accuracy Rating', 'Cleanliness Rating',
#        'Checkin Rating', 'Communication Rating', 'Location Rating',
#        'Value Rating', 'Reviews', 'Bedrooms', 'Beds', 'Bathrooms',
#        'Is Superhost', 'Latitude', 'Longitude', 'Accomodates',
#        'Guests Included', 'Min Nights', 'Instant Bookable',
#        'Is Exact Location', 'Postal Code', 'Property Type',
#        'Host Response Time', 'Neighborhood Group', 'Room Type',
#        'Distance From Center', 'Distance From Center Grouped',
#        'Host Since Year Old', 'Price'],
#       dtype='object')

# %%
df2 = df[nm].copy()
df2.head()
# Out:
#    Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0           100.0             10.0                10.0            10.0
# 1            92.0              9.0                 9.0             9.0
# 2            96.0             10.0                10.0            10.0
# 3           100.0             10.0                10.0            10.0
# 4            93.0             10.0                10.0             9.0
#
#    Communication Rating  Location Rating  Value Rating  Reviews  Bedrooms  \
# 0                  10.0              9.0          10.0      7.0       1.0
# 1                   9.0             10.0           9.0    144.0       1.0
# 2                  10.0             10.0          10.0    229.0       1.0
# 3                  10.0             10.0          10.0      6.0       4.0
# 4                  10.0              9.0           9.0     23.0       0.0
#
#    Beds  Bathrooms  Is Superhost  Latitude  Longitude  Accomodates  \
# 0   1.0        1.0         False  52.54851   13.40455          2.0
# 1   2.0        1.0         False  52.53500   13.41758          4.0
# 2   2.0        1.0          True  52.54316   13.41509          2.0
# 3   7.0        0.0         False  52.53303   13.41605          0.0
# 4   1.0        1.0         False  52.54785   13.40556          1.0
#
#    Guests Included  Min Nights  Instant Bookable  Is Exact Location  \
# 0              1.0         2.0             False               True
# 1              2.0         0.0             False               True
# 2              1.0         2.0             False               True
# 3              5.0         6.0             False              False
# 4              1.0         0.0             False               True
#
#    Postal Code  Property Type  Host Response Time  Neighborhood Group  \
# 0           24              1                   2                   6
# 1           18              1                   2                   6
# 2           24              1                   4                   6
# 3           18              1                   2                   6
# 4           24              1                   2                   6
#
#    Room Type  Distance From Center  Distance From Center Grouped  \
# 0          1                   5.1                             9
# 1          0                   3.7                             8
# 2          1                   4.6                             9
# 3          0                   3.5                             8
# 4          0                   5.0                             9
#
#    Host Since Year Old  Price
# 0                   17   17.0
# 1                   17   90.0
# 2                   16   33.0
# 3                   16  180.0
# 4                   16   70.0

# %% [markdown]
# #Multivariable Analysis

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.linear_model import Ridge

# %%
### drop na
df2 = df2.dropna()
df.shape
# Out:
# (23536, 28)

# %%
## remove unnecessary vars
X = df2.iloc[:,:-1]
X
# Out:
#        Overall Rating  Accuracy Rating  Cleanliness Rating  Checkin Rating  \
# 0               100.0             10.0                10.0            10.0
# 1                92.0              9.0                 9.0             9.0
# 2                96.0             10.0                10.0            10.0
# 3               100.0             10.0                10.0            10.0
# 4                93.0             10.0                10.0             9.0
# ...               ...              ...                 ...             ...
# 23531           100.0             10.0                10.0            10.0
# 23532            60.0              6.0                 6.0             8.0
# 23533           100.0             10.0                10.0            10.0
# 23534            80.0              8.0                 8.0            10.0
# 23535           100.0             10.0                 9.0            10.0
#
#        Communication Rating  Location Rating  Value Rating  Reviews  Bedrooms  \
# 0                      10.0              9.0          10.0      7.0       1.0
# 1                       9.0             10.0           9.0    144.0       1.0
# 2                      10.0             10.0          10.0    229.0       1.0
# 3                      10.0             10.0          10.0      6.0       4.0
# 4                      10.0              9.0           9.0     23.0       0.0
# ...                     ...              ...           ...      ...       ...
# 23531                   9.0              9.0          10.0      0.0       1.0
# 23532                   8.0              6.0           6.0      0.0       2.0
# 23533                  10.0              8.0           8.0      0.0       1.0
# 23534                  10.0              7.0           7.0      0.0       3.0
# 23535                  10.0              9.0           9.0      0.0       2.0
#
#        Beds  Bathrooms  Is Superhost  Latitude  Longitude  Accomodates  \
# 0       1.0        1.0         False  52.54851   13.40455          2.0
# 1       2.0        1.0         False  52.53500   13.41758          4.0
# 2       2.0        1.0          True  52.54316   13.41509          2.0
# 3       7.0        0.0         False  52.53303   13.41605          0.0
# 4       1.0        1.0         False  52.54785   13.40556          1.0
# ...     ...        ...           ...       ...        ...          ...
# 23531   2.0        1.0         False  52.42278   13.16120          3.0
# 23532   2.0        1.0         False  52.63020   13.49340          2.0
# 23533   1.0        0.0         False  52.45402   13.43864          1.0
# 23534   4.0        1.0         False  52.47342   13.58483          0.0
# 23535   2.0        1.0         False  52.54929   13.46067          3.0
#
#        Guests Included  Min Nights  Instant Bookable  Is Exact Location  \
# 0                  1.0         2.0             False               True
# 1                  2.0         0.0             False               True
# 2                  1.0         2.0             False               True
# 3                  5.0         6.0             False              False
# 4                  1.0         0.0             False               True
# ...                ...         ...               ...                ...
# 23531              1.0         0.0              True              False
# 23532              2.0         5.0              True               True
# 23533              1.0         2.0              True               True
# 23534              1.0         2.0              True               True
# 23535              1.0         2.0              True              False
#
#        Postal Code  Property Type  Host Response Time  Neighborhood Group  \
# 0               24              1                   2                   6
# 1               18              1                   2                   6
# 2               24              1                   4                   6
# 3               18              1                   2                   6
# 4               24              1                   2                   6
# ...            ...            ...                 ...                 ...
# 23531          184              1                   3                   9
# 23532          137              1                   1                   6
# 23533           98              1                   1                   5
# 23534          114              1                   1                  11
# 23535          135              1                   1                   6
#
#        Room Type  Distance From Center  Distance From Center Grouped  \
# 0              1                   5.1                             9
# 1              0                   3.7                             8
# 2              1                   4.6                             9
# 3              0                   3.5                             8
# 4              0                   5.0                             9
# ...          ...                   ...                           ...
# 23531          0                  18.7                             7
# 23532          1                  15.4                             5
# 23533          1                   5.9                             9
# 23534          0                  12.7                             4
# 23535          0                   6.4                            10
#
#        Host Since Year Old
# 0                       17
# 1                       17
# 2                       16
# 3                       16
# 4                       16
# ...                    ...
# 23531                    7
# 23532                    6
# 23533                   11
# 23534                    6
# 23535                    7
#
# [23536 rows x 27 columns]

# %%
y = df2.iloc[:,-1:]
print([X.shape,y.shape])
# Out:
# [(23536, 27), (23536, 1)]

# %% [markdown]
# ##Variable Selection using LASSO (L1 penalization)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
lassomod = Lasso(alpha=0.01).fit(X, y)
model = SelectFromModel(lassomod, prefit=True)
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
varSel['Lasso'] = model.get_support().astype('int64')

# %% [markdown]
# ##Variable Selection using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel

rfmod = RandomForestRegressor().fit(X, y)
model = SelectFromModel(rfmod, prefit=True)
model.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False,  True,  True, False,  True, False, False,
#         True, False,  True, False, False, False,  True, False, False])

# %%
varSel['RandomForest'] = model.get_support().astype('int64')

# %% [markdown]
# ##Variable Selection using Gradient Boosting classification

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel

gbmod = GradientBoostingClassifier().fit(X, y)
model = SelectFromModel(gbmod, prefit=True)
model.get_support()
# Out:
# array([False, False, False, False, False,  True, False,  True,  True,
#         True, False, False, False,  True, False,  True,  True, False,
#        False,  True,  True, False, False,  True, False, False, False])

# %%
varSel['GradientBoost'] = model.get_support().astype('int64')

# %% [markdown]
# ##Variable Selection using SVM classification

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

svmmod = LinearSVC(C=0.01, penalty="l1",dual=False).fit(X, y)
model = SelectFromModel(svmmod, prefit=True)
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False,  True,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True])

# %%
varSel['SVM'] = model.get_support().astype('int64')

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

elastic_net = ElasticNet(alpha=0.1, l1_ratio=0.5, random_state=42)
elastic_net.fit(X, y)

# Use SelectFromModel to extract important features
selector = SelectFromModel(elastic_net, prefit=True)  # Prefit=True means model is already trained
selector.get_support()  # Boolean mask for selected features
# Out:
# array([False, False, False,  True, False,  True,  True, False,  True,
#        False, False, False, False,  True, False,  True, False,  True,
#         True, False, False, False, False,  True, False, False, False])

# %%
varSel['elastic_net'] = selector.get_support().astype('int64')

# %% [markdown]
# ##Summarization and Selection of Variables

# %%
varSel.head(30)
# Out:
#                         Variable  Lasso  RandomForest  GradientBoost  SVM  \
# 0                 Overall Rating      1             0              0    1
# 1                Accuracy Rating      1             0              0    1
# 2             Cleanliness Rating      1             0              0    1
# 3                 Checkin Rating      1             0              0    1
# 4           Communication Rating      1             0              0    1
# 5                Location Rating      1             0              1    1
# 6                   Value Rating      1             0              0    1
# 7                        Reviews      1             0              1    1
# 8                       Bedrooms      1             0              1    1
# 9                           Beds      1             0              1    1
# 10                     Bathrooms      1             0              0    0
# 11                  Is Superhost      1             0              0    0
# 12                      Latitude      1             1              0    1
# 13                     Longitude      1             1              1    1
# 14                   Accomodates      1             0              0    1
# 15               Guests Included      1             1              1    1
# 16                    Min Nights      1             0              1    1
# 17              Instant Bookable      1             0              0    0
# 18             Is Exact Location      1             1              0    1
# 19                   Postal Code      1             0              1    1
# 20                 Property Type      1             1              1    1
# 21            Host Response Time      1             0              0    1
# 22            Neighborhood Group      1             0              0    1
# 23                     Room Type      1             0              1    1
# 24          Distance From Center      1             1              0    1
# 25  Distance From Center Grouped      1             0              0    1
# 26           Host Since Year Old      1             0              0    1
#
#     Sum  elastic_net
# 0     2            0
# 1     2            0
# 2     2            0
# 3     3            1
# 4     2            0
# 5     4            1
# 6     3            1
# 7     3            0
# 8     4            1
# 9     3            0
# 10    1            0
# 11    1            0
# 12    3            0
# 13    5            1
# 14    2            0
# 15    5            1
# 16    3            0
# 17    2            1
# 18    4            1
# 19    3            0
# 20    4            0
# 21    2            0
# 22    2            0
# 23    4            1
# 24    3            0
# 25    2            0
# 26    2            0

# %%
varSel['Sum'] =  np.sum(varSel[["Lasso",	"RandomForest",	"GradientBoost"	,"SVM","elastic_net"]],axis=1)
varSel
# Out:
#                         Variable  Lasso  RandomForest  GradientBoost  SVM  \
# 0                 Overall Rating      1             0              0    1
# 1                Accuracy Rating      1             0              0    1
# 2             Cleanliness Rating      1             0              0    1
# 3                 Checkin Rating      1             0              0    1
# 4           Communication Rating      1             0              0    1
# 5                Location Rating      1             0              1    1
# 6                   Value Rating      1             0              0    1
# 7                        Reviews      1             0              1    1
# 8                       Bedrooms      1             0              1    1
# 9                           Beds      1             0              1    1
# 10                     Bathrooms      1             0              0    0
# 11                  Is Superhost      1             0              0    0
# 12                      Latitude      1             1              0    1
# 13                     Longitude      1             1              1    1
# 14                   Accomodates      1             0              0    1
# 15               Guests Included      1             1              1    1
# 16                    Min Nights      1             0              1    1
# 17              Instant Bookable      1             0              0    0
# 18             Is Exact Location      1             1              0    1
# 19                   Postal Code      1             0              1    1
# 20                 Property Type      1             1              1    1
# 21            Host Response Time      1             0              0    1
# 22            Neighborhood Group      1             0              0    1
# 23                     Room Type      1             0              1    1
# 24          Distance From Center      1             1              0    1
# 25  Distance From Center Grouped      1             0              0    1
# 26           Host Since Year Old      1             0              0    1
#
#     Sum  elastic_net
# 0     2            0
# 1     2            0
# 2     2            0
# 3     3            1
# 4     2            0
# 5     4            1
# 6     3            1
# 7     3            0
# 8     4            1
# 9     3            0
# 10    1            0
# 11    1            0
# 12    3            0
# 13    5            1
# 14    2            0
# 15    5            1
# 16    3            0
# 17    2            1
# 18    4            1
# 19    3            0
# 20    4            0
# 21    2            0
# 22    2            0
# 23    4            1
# 24    3            0
# 25    2            0
# 26    2            0

# %%
varSel.groupby('Sum')['Variable'].count()
# Out:
# Sum
# 1     2
# 2    10
# 3     8
# 4     5
# 5     2
# Name: Variable, dtype: int64

# %%
varSel[varSel['Sum']==5]
# Out:
#            Variable  Lasso  RandomForest  GradientBoost  SVM  Sum  elastic_net
# 13        Longitude      1             1              1    1    5            1
# 15  Guests Included      1             1              1    1    5            1

# %%
varSel[varSel['Sum']>=4]
# Out:
#              Variable  Lasso  RandomForest  GradientBoost  SVM  Sum  \
# 5     Location Rating      1             0              1    1    4
# 8            Bedrooms      1             0              1    1    4
# 13          Longitude      1             1              1    1    5
# 15    Guests Included      1             1              1    1    5
# 18  Is Exact Location      1             1              0    1    4
# 20      Property Type      1             1              1    1    4
# 23          Room Type      1             0              1    1    4
#
#     elastic_net
# 5             1
# 8             1
# 13            1
# 15            1
# 18            1
# 20            0
# 23            1

# %%
varSel[varSel['Sum']>=3]
# Out:
#                 Variable  Lasso  RandomForest  GradientBoost  SVM  Sum  \
# 3         Checkin Rating      1             0              0    1    3
# 5        Location Rating      1             0              1    1    4
# 6           Value Rating      1             0              0    1    3
# 7                Reviews      1             0              1    1    3
# 8               Bedrooms      1             0              1    1    4
# 9                   Beds      1             0              1    1    3
# 12              Latitude      1             1              0    1    3
# 13             Longitude      1             1              1    1    5
# 15       Guests Included      1             1              1    1    5
# 16            Min Nights      1             0              1    1    3
# 18     Is Exact Location      1             1              0    1    4
# 19           Postal Code      1             0              1    1    3
# 20         Property Type      1             1              1    1    4
# 23             Room Type      1             0              1    1    4
# 24  Distance From Center      1             1              0    1    3
#
#     elastic_net
# 3             1
# 5             1
# 6             1
# 7             0
# 8             1
# 9             0
# 12            0
# 13            1
# 15            1
# 16            0
# 18            1
# 19            0
# 20            0
# 23            1
# 24            0

# %%
varSel[varSel['Sum']>=2]
# Out:
#                         Variable  Lasso  RandomForest  GradientBoost  SVM  \
# 0                 Overall Rating      1             0              0    1
# 1                Accuracy Rating      1             0              0    1
# 2             Cleanliness Rating      1             0              0    1
# 3                 Checkin Rating      1             0              0    1
# 4           Communication Rating      1             0              0    1
# 5                Location Rating      1             0              1    1
# 6                   Value Rating      1             0              0    1
# 7                        Reviews      1             0              1    1
# 8                       Bedrooms      1             0              1    1
# 9                           Beds      1             0              1    1
# 12                      Latitude      1             1              0    1
# 13                     Longitude      1             1              1    1
# 14                   Accomodates      1             0              0    1
# 15               Guests Included      1             1              1    1
# 16                    Min Nights      1             0              1    1
# 17              Instant Bookable      1             0              0    0
# 18             Is Exact Location      1             1              0    1
# 19                   Postal Code      1             0              1    1
# 20                 Property Type      1             1              1    1
# 21            Host Response Time      1             0              0    1
# 22            Neighborhood Group      1             0              0    1
# 23                     Room Type      1             0              1    1
# 24          Distance From Center      1             1              0    1
# 25  Distance From Center Grouped      1             0              0    1
# 26           Host Since Year Old      1             0              0    1
#
#     Sum  elastic_net
# 0     2            0
# 1     2            0
# 2     2            0
# 3     3            1
# 4     2            0
# 5     4            1
# 6     3            1
# 7     3            0
# 8     4            1
# 9     3            0
# 12    3            0
# 13    5            1
# 14    2            0
# 15    5            1
# 16    3            0
# 17    2            1
# 18    4            1
# 19    3            0
# 20    4            0
# 21    2            0
# 22    2            0
# 23    4            1
# 24    3            0
# 25    2            0
# 26    2            0

# %%
varSel.to_csv("/content/drive/MyDrive/kaggle/berline/feature_selection_results.csv")
